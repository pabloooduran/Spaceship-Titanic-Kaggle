# %% [markdown]
# ## Imports

# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('spaceship-titanic')

print("Path to competition files:", path)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Visualization

# %%
train_df = pd.read_csv(path + '/' + 'train.csv')
train_df.head()

# %%
for col in train_df.columns:
    print(f"Column: {col}, Data Type: {train_df[col].dtype}, Unique Values: {train_df[col].nunique()}, Missing Values: {train_df[col].isnull().sum()}")

# %%
test_df = pd.read_csv(path + '/' + 'test.csv')
test_df.head()

# %% [markdown]
# ## Formato de entrega

# %%
submission_df = pd.read_csv(path + '/' + 'sample_submission.csv')
submission_df.head()

# %%
train_df[train_df["HomePlanet"].isnull()]

# %%
print("Hello")
